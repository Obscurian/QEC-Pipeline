# %%
import numpy as np
import matplotlib.pyplot as plt
import networkx as nx
import seaborn as sns
import pytest
import qiskit
import qiskit_aer
from classes_and_functions import *

# %%
import warnings

warnings.warn("this is a test")
# Out:
# /var/folders/nq/5x0907g93k947rr4qhxsbr4w0000gp/T/ipykernel_20287/272769145.py:3: UserWarning: this is a test
#   warnings.warn("this is a test")
